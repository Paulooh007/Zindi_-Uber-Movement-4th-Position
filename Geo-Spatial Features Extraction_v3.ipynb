# %% [markdown]
# ## 7. Geo-Spatial Features

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
import pandas_profiling as pf 
import os
import numpy as np
import seaborn as sns
import matplotlib as plt
pd.options.mode.chained_assignment = None
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\tqdm\std.py:656: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='my_app',timeout=None)

from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ### Extraction for a geo-coordinates

# %%
location = geolocator.reverse("-33.902, 18.675")
location.raw['address']
# Out:
# {'suburb': 'Cape Town Ward 3',
#  'town': 'Bellville',
#  'county': 'City of Cape Town',
#  'state': 'Western Cape',
#  'country': 'South Africa',
#  'country_code': 'za'}

# %% [markdown]
# ### GeoData Creation

# %%
GeoData = pd.read_csv('Data/MergedData.csv')
GeoData = GeoData[['segment_id','EventId','latitude', 'longitude']]
display(GeoData.head(2))
print(GeoData.shape)
# Out:
#   segment_id  EventId   latitude  longitude
# 0    S0B3CGQ    60558 -33.888275  18.540896
# 1    RYJYAPI    60559 -34.140857  18.930756
# (53845, 4)

# %% [markdown]
# ### GeoCoordinates Rounding

# %%
# Rounding off to 2 decimal places
GeoData['latitudeX'] = GeoData.latitude.round(3)
GeoData['longitudeX'] = GeoData.longitude.round(3)
display(GeoData.head(2))
print('GeoData size = ',len(GeoData))
# Out:
#   segment_id  EventId   latitude  longitude  latitudeX  longitudeX
# 0    S0B3CGQ    60558 -33.888275  18.540896    -33.888      18.541
# 1    RYJYAPI    60559 -34.140857  18.930756    -34.141      18.931
# GeoData size =  53845

# %%
GeoData.to_csv('Data/Geo_Rounding.csv', index=None)

# %% [markdown]
# ### Dropping duplicates in latitudeX & latitudeX

# %%
#Combining latitudeX & latitudeX
GeoData['LatLong'] = GeoData.latitudeX.astype('str')+'+'+GeoData.longitudeX.astype('str')
GeoData[:1]
# Out:
#   segment_id  EventId   latitude  longitude  latitudeX  longitudeX  \
# 0    S0B3CGQ    60558 -33.888275  18.540896    -33.888      18.541
#
#           LatLong
# 0  -33.888+18.541

# %%
# GeoData slim
GeoDataX = GeoData.drop_duplicates(['LatLong'], keep='last')
# Reset index
GeoDataX.reset_index(drop=True, inplace=True)
display(GeoDataX.head(2))
print('GeoDataX size = ',len(GeoDataX))
# Out:
#   segment_id  EventId   latitude  longitude  latitudeX  longitudeX  \
# 0    X4UA382    60564 -33.885498  18.638471    -33.885      18.638
# 1    SPPGKO2    60578 -33.855022  18.531405    -33.855      18.531
#
#           LatLong
# 0  -33.885+18.638
# 1  -33.855+18.531
# GeoDataX size =  2215

# %%
#Dropping LatLong
del GeoDataX['LatLong']

# %% [markdown]
# ### Saving the data

# %%
GeoDataX.to_csv('Data/geodata/geolocation.csv', index=None)

# %% [markdown]
# ### Extracting the geo info for the data frmae

# %%
def get_suburb(row):
    pos = str(row['latitudeX']) + ', ' + str(row['longitudeX'])
    location = geolocator.reverse(pos)
    return location.raw['address']

# %%
GeoDataX['address'] = GeoDataX[['latitudeX','longitudeX']].progress_apply(get_suburb,axis=1)
#Saving the results
GeoDataX.to_csv('Data/GeoDataX_New.csv',index=None)
GeoDataX[:2]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2215/2215 [29:00<00:00,  1.27it/s]
#    EventId   latitude  longitude  latitudeX  longitudeX  \
# 0    60564 -33.885498  18.638471    -33.885      18.638
# 1    60578 -33.855022  18.531405    -33.855      18.531
#
#                                              address
# 0  {'road': 'Springfield Road', 'suburb': 'Cape T...
# 1  {'road': 'N7', 'suburb': 'Milnerton', 'city': ...

# %%
GeoDataX =pd.read_csv('Data/GeoDataX_New.csv')
GeoDataX[:2]
# Out:
#    EventId   latitude  longitude  latitudeX  longitudeX  \
# 0    60564 -33.885498  18.638471    -33.885      18.638
# 1    60578 -33.855022  18.531405    -33.855      18.531
#
#                                              address
# 0  {'road': 'Springfield Road', 'suburb': 'Cape T...
# 1  {'road': 'N7', 'suburb': 'Milnerton', 'city': ...

# %%
GeoDataMerged =pd.read_csv('Data/GeoDataRetrieved_PythonVersion.csv')
GeoDataMerged.reset_index(drop=True, inplace=True)
print(GeoDataMerged.shape)
display(GeoDataMerged.head(2))
# Out:
# (2215, 8)
#    EventId   latitude  longitude  latitudeX  longitudeX  SN  \
# 0    60564 -33.885498  18.638471    -33.885      18.638   1
# 1    60578 -33.855022  18.531405    -33.855      18.531   2
#
#                                               suburb  \
# 0  {'suburb': 'Cape Town Ward 3', 'town': 'Bellvi...
# 1  {'suburb': 'Cape Town Ward 3', 'town': 'Bellvi...
#
#                                              address
# 0  {'road': 'Springfield Road', 'suburb': 'Cape T...
# 1  {'road': 'N7', 'suburb': 'Milnerton', 'city': ...

# %%
#Dropping LatLong
del GeoDataMerged['suburb']

# %% [markdown]
# ### Extracting Suburb, Town, County,

# %%
GeoDataMerged['address'][0]
# Out:
# "{'road': 'Springfield Road', 'suburb': 'Cape Town Ward 21', 'town': 'Bellville', 'county': 'City of Cape Town', 'state': 'Western Cape', 'postcode': '7530', 'country': 'South Africa', 'country_code': 'za'}"

# %%
# Checking the data type
type({'suburb': 'Cape Town Ward 3',
 'town': 'Bellville',
 'county': 'City of Cape Town',
 'state': 'Western Cape',
 'country': 'South Africa',
 'country_code': 'za'})
# Out:
# dict

# %% [markdown]
# ### Splitting  the dictionary column to pandas coulumn

# %%
import ast

# %%
GeoDataMergedx=GeoDataMerged['address'].apply(ast.literal_eval).apply(pd.Series)
GeoDataMergedx.reset_index(drop=True, inplace=True)
display(GeoDataMergedx.head(2))
print('GeoDataMergedx = ', GeoDataMergedx.shape)
# Out:
#                road             suburb       town             county  \
# 0  Springfield Road  Cape Town Ward 21  Bellville  City of Cape Town
# 1                N7          Milnerton        NaN  City of Cape Town
#
#           state postcode       country country_code       city neighbourhood  \
# 0  Western Cape     7530  South Africa           za        NaN           NaN
# 1  Western Cape     7441  South Africa           za  Cape Town           NaN
#
#    ... restaurant pitch hotel doityourself parking bus_stop footway station  \
# 0  ...        NaN   NaN   NaN          NaN     NaN      NaN     NaN     NaN
# 1  ...        NaN   NaN   NaN          NaN     NaN      NaN     NaN     NaN
#
#   toilets police
# 0     NaN    NaN
# 1     NaN    NaN
#
# [2 rows x 49 columns]
# GeoDataMergedx =  (2215, 49)

# %% [markdown]
# ### Selecting the columns of interest

# %%
GeoDataMergedx = GeoDataMergedx[['road','suburb','town','state','city']]
GeoDataMergedx.head(2)
# Out:
#                road             suburb       town         state       city
# 0  Springfield Road  Cape Town Ward 21  Bellville  Western Cape        NaN
# 1                N7          Milnerton        NaN  Western Cape  Cape Town

# %% [markdown]
# ### Checking the Completeness

# %%
GeoDataMergedx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215 entries, 0 to 2214
# Data columns (total 5 columns):
# road      2134 non-null object
# suburb    2215 non-null object
# town      825 non-null object
# state     2215 non-null object
# city      1195 non-null object
# dtypes: object(5)
# memory usage: 86.6+ KB

# %% [markdown]
# ### Merging the GeoDataMergedx with GeoDataMerged Dataset with

# %%
GeoDataMergedY = GeoDataX.join(GeoDataMergedx, how='outer')
print(GeoDataMergedY.shape)
GeoDataMergedY[:4]
# Out:
# (2215, 10)
#    EventId   latitude  longitude  latitudeX  longitudeX              road  \
# 0    60564 -33.885498  18.638471    -33.885      18.638  Springfield Road
# 1    60578 -33.855022  18.531405    -33.855      18.531                N7
# 2    60684 -33.796500  18.882241    -33.796      18.882                N1
# 3    60701 -34.068404  18.810695    -34.068      18.811     Old Main Road
#
#                  suburb       town         state  \
# 0     Cape Town Ward 21  Bellville  Western Cape
# 1             Milnerton        NaN  Western Cape
# 2  Stellenbosch Ward 18        NaN  Western Cape
# 3     Cape Town Ward 15        NaN  Western Cape
#
#                               city
# 0                              NaN
# 1                        Cape Town
# 2  Stellenbosch Local Municipality
# 3                              NaN

# %%
GeoDataMergedY.to_csv('Data/GeoDataMergedY.csv', index = None)

# %% [markdown]
# ### Extracting the Suburb Bounding Box and Geo-Coordinates

# %% [markdown]
# ### Dropping the duplicates in Suburb column

# %%
GeoDataMergedY = GeoDataMergedY.drop_duplicates(['suburb'], keep='last')
GeoDataMergedY.reset_index(drop=True, inplace=True)
display(GeoDataMergedY.head(2))
print('GeoDataMergedY size = ',len(GeoDataMergedY))
# Out:
#    EventId   latitude  longitude  latitudeX  longitudeX               road  \
# 0    63216 -33.952298  18.465721    -33.952      18.466       Rhodes Drive
# 1   138883 -33.888280  18.564370    -33.888      18.564  Giel Basson Drive
#
#       suburb   town         state       city
# 0   Rosebank    NaN  Western Cape  Cape Town
# 1  Kaapzicht  Parow  Western Cape        NaN
# GeoDataMergedY size =  102

# %%
GeoDataMergedY.to_csv('Data/GeoDataMergedY.csv', index = None)

# %% [markdown]
# ### Adding the suffix "Cape Town"
# This is because rosebamk, exist in the other part of SA and world

# %%
GeoDataMergedY['suburb_long'] = GeoDataMergedY.suburb + '' + ' Cape Town'
GeoDataMergedY['suburb_long'].head(2)
# Out:
# 0     Rosebank Cape Town
# 1    Kaapzicht Cape Town
# Name: suburb_long, dtype: object

# %%
GeoDataMergedY.head(2)
# Out:
#    EventId   latitude  longitude  latitudeX  longitudeX               road  \
# 0    63216 -33.952298  18.465721    -33.952      18.466       Rhodes Drive
# 1   138883 -33.888280  18.564370    -33.888      18.564  Giel Basson Drive
#
#       suburb   town         state       city          suburb_long
# 0   Rosebank    NaN  Western Cape  Cape Town   Rosebank Cape Town
# 1  Kaapzicht  Parow  Western Cape        NaN  Kaapzicht Cape Town

# %% [markdown]
# ### Geo-coding the suburb to get the bouding box and geo-coordinates

# %%
location = geolocator.geocode("Plattekloof, Cape Town")
location.raw
# Out:
# {'place_id': 198287243,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 2051480,
#  'boundingbox': ['-33.8886906', '-33.8615971', '18.5715808', '18.6003196'],
#  'lat': '-33.8775',
#  'lon': '18.5855556',
#  'display_name': 'Plattekloof, Parow, City of Cape Town, Western Cape, South Africa',
#  'class': 'place',
#  'type': 'suburb',
#  'importance': 0.56,
#  'icon': 'https://nominatim.openstreetmap.org/images/mapicons/poi_place_village.p.20.png'}

# %%
GeoDataMergedY.shape

# %%
boundary = [[-33, 20], [-35, 18]]
def get_geocodinate_bounding_box(row):
    pos = str(row['suburb'])
    locations =  RateLimiter(geolocator.geocode(pos, country_codes = 'za', viewbox=boundary, bounded=True), min_delay_seconds=1)          
    return locations

# %%
## query the server(geopy) and return the location as a function
GeoDataMergedY['func'] = GeoDataMergedY[['suburb']].progress_apply(get_geocodinate_bounding_box,axis=1)
GeoDataMergedY[:2]
# Out:
#   0%|                                                                                          | 0/102 [00:00<?, ?it/s]
#
#
#
#   2%|█▌                                                                                | 2/102 [00:00<00:38,  2.60it/s]
#
#
#
#   3%|██▍                                                                               | 3/102 [00:01<00:49,  1.99it/s]
#
#
#
#   4%|███▏                                                                              | 4/102 [00:02<00:56,  1.73it/s]
#
#
#
#   5%|████                                                                              | 5/102 [00:03<01:01,  1.57it/s]
#
#
#
#   6%|████▊                                                                             | 6/102 [00:03<01:06,  1.45it/s]
#
#
#
#   7%|█████▋                                                                            | 7/102 [00:04<01:07,  1.40it/s]
#
#
#
#   8%|██████▍                                                                           | 8/102 [00:05<01:07,  1.38it/s]
#
#
#
#   9%|███████▏                                                                          | 9/102 [00:06<01:08,  1.36it/s]
#
#
#
#  10%|███████▉                                                                         | 10/102 [00:06<01:09,  1.32it/s]
#
#
#
#  11%|████████▋                                                                        | 11/102 [00:07<01:10,  1.28it/s]
#
#
#
#  12%|█████████▌                                                                       | 12/102 [00:08<01:09,  1.29it/s]
#
#
#
#  13%|██████████▎                                                                      | 13/102 [00:09<01:08,  1.30it/s]
#
#
#
#  14%|███████████                                                                      | 14/102 [00:10<01:07,  1.31it/s]
#
#
#
#  15%|███████████▉                                                                     | 15/102 [00:11<01:33,  1.07s/it]
#
#
#
#  16%|████████████▋                                                                    | 16/102 [00:12<01:24,  1.01it/s]
#
#
#
#  17%|█████████████▌                                                                   | 17/102 [00:13<01:18,  1.08it/s]
#
#
#
#  18%|██████████████▎                                                                  | 18/102 [00:14<01:13,  1.14it/s]
#
#
#
#  19%|███████████████                                                                  | 19/102 [00:14<01:10,  1.18it/s]
#
#
#
#  20%|███████████████▉                                                                 | 20/102 [00:15<01:07,  1.22it/s]
#
#
#
#  21%|████████████████▋                                                                | 21/102 [00:16<01:04,  1.25it/s]
#
#
#
#  22%|█████████████████▍                                                               | 22/102 [00:17<01:02,  1.28it/s]
#
#
#
#  23%|██████████████████▎                                                              | 23/102 [00:18<01:02,  1.27it/s]
#
#
#
#  24%|███████████████████                                                              | 24/102 [00:18<01:01,  1.28it/s]
#
#
#
#  25%|███████████████████▊                                                             | 25/102 [00:19<00:59,  1.29it/s]
#
#
#
#  25%|████████████████████▋                                                            | 26/102 [00:20<00:58,  1.30it/s]
#
#
#
#  26%|█████████████████████▍                                                           | 27/102 [00:21<00:57,  1.30it/s]
#
#
#
#  27%|██████████████████████▏                                                          | 28/102 [00:21<00:56,  1.30it/s]
#
#
#
#  28%|███████████████████████                                                          | 29/102 [00:22<00:55,  1.31it/s]
#
#
#
#  29%|███████████████████████▊                                                         | 30/102 [00:24<01:19,  1.11s/it]
#
#
#
#  30%|████████████████████████▌                                                        | 31/102 [00:25<01:11,  1.01s/it]
#
#
#
#  31%|█████████████████████████▍                                                       | 32/102 [00:26<01:05,  1.06it/s]
#
#
#
#  32%|██████████████████████████▏                                                      | 33/102 [00:26<01:01,  1.13it/s]
#
#
#
#  33%|███████████████████████████                                                      | 34/102 [00:27<00:59,  1.15it/s]
#
#
#
#  34%|███████████████████████████▊                                                     | 35/102 [00:28<00:56,  1.19it/s]
#
#
#
#  35%|████████████████████████████▌                                                    | 36/102 [00:29<00:54,  1.20it/s]
#
#
#
#  36%|█████████████████████████████▍                                                   | 37/102 [00:30<00:52,  1.23it/s]
#
#
#
#  37%|██████████████████████████████▏                                                  | 38/102 [00:30<00:51,  1.25it/s]
#
#
#
#  38%|██████████████████████████████▉                                                  | 39/102 [00:31<00:50,  1.24it/s]
#
#
#
#  39%|███████████████████████████████▊                                                 | 40/102 [00:32<00:49,  1.25it/s]
#
#
#
#  40%|████████████████████████████████▌                                                | 41/102 [00:33<00:48,  1.27it/s]
#
#
#
#  41%|█████████████████████████████████▎                                               | 42/102 [00:33<00:47,  1.27it/s]
#
#
#
#  42%|██████████████████████████████████▏                                              | 43/102 [00:34<00:47,  1.24it/s]
#
#
#
#  43%|██████████████████████████████████▉                                              | 44/102 [00:35<00:46,  1.25it/s]
#
#
#
#  44%|███████████████████████████████████▋                                             | 45/102 [00:36<00:45,  1.26it/s]
#
#
#
#  45%|████████████████████████████████████▌                                            | 46/102 [00:37<00:44,  1.27it/s]
#
#
#
#  46%|█████████████████████████████████████▎                                           | 47/102 [00:38<00:51,  1.06it/s]
#
#
#
#  47%|██████████████████████████████████████                                           | 48/102 [00:39<00:48,  1.12it/s]
#
#
#
#  48%|██████████████████████████████████████▉                                          | 49/102 [00:40<00:46,  1.14it/s]
#
#
#
#  49%|███████████████████████████████████████▋                                         | 50/102 [00:40<00:43,  1.18it/s]
#
#
#
#  50%|████████████████████████████████████████▌                                        | 51/102 [00:41<00:42,  1.20it/s]
#
#
#
#  51%|█████████████████████████████████████████▎                                       | 52/102 [00:42<00:41,  1.22it/s]
#
#
#
#  52%|██████████████████████████████████████████                                       | 53/102 [00:43<00:39,  1.24it/s]
#
#
#
#  53%|██████████████████████████████████████████▉                                      | 54/102 [00:44<00:38,  1.24it/s]
#
#
#
#  54%|███████████████████████████████████████████▋                                     | 55/102 [00:44<00:37,  1.25it/s]
#
#
#
#  55%|████████████████████████████████████████████▍                                    | 56/102 [00:45<00:37,  1.24it/s]
#
#
#
#  56%|█████████████████████████████████████████████▎                                   | 57/102 [00:46<00:35,  1.27it/s]
#
#
#
#  57%|██████████████████████████████████████████████                                   | 58/102 [00:47<00:34,  1.28it/s]
#
#
#
#  58%|██████████████████████████████████████████████▊                                  | 59/102 [00:47<00:34,  1.26it/s]
#
#
#
#  59%|███████████████████████████████████████████████▋                                 | 60/102 [00:48<00:32,  1.27it/s]
#
#
#
#  60%|████████████████████████████████████████████████▍                                | 61/102 [00:49<00:32,  1.28it/s]
#
#
#
#  61%|█████████████████████████████████████████████████▏                               | 62/102 [00:50<00:31,  1.29it/s]
#
#
#
#  62%|██████████████████████████████████████████████████                               | 63/102 [00:51<00:30,  1.29it/s]
#
#
#
#  63%|██████████████████████████████████████████████████▊                              | 64/102 [00:51<00:29,  1.29it/s]
#
#
#
#  64%|███████████████████████████████████████████████████▌                             | 65/102 [00:52<00:28,  1.28it/s]
#
#
#
#  65%|████████████████████████████████████████████████████▍                            | 66/102 [00:53<00:28,  1.26it/s]
#
#
#
#  66%|█████████████████████████████████████████████████████▏                           | 67/102 [00:54<00:27,  1.27it/s]
#
#
#
#  67%|██████████████████████████████████████████████████████                           | 68/102 [00:54<00:26,  1.29it/s]
#
#
#
#  68%|██████████████████████████████████████████████████████▊                          | 69/102 [00:55<00:25,  1.28it/s]
#
#
#
#  69%|███████████████████████████████████████████████████████▌                         | 70/102 [00:56<00:24,  1.28it/s]
#
#
#
#  70%|████████████████████████████████████████████████████████▍                        | 71/102 [00:57<00:23,  1.30it/s]
#
#
#
#  71%|█████████████████████████████████████████████████████████▏                       | 72/102 [00:57<00:22,  1.31it/s]
#
#
#
#  72%|█████████████████████████████████████████████████████████▉                       | 73/102 [00:58<00:22,  1.29it/s]
#
#
#
#  73%|██████████████████████████████████████████████████████████▊                      | 74/102 [00:59<00:21,  1.30it/s]
#
#
#
#  74%|███████████████████████████████████████████████████████████▌                     | 75/102 [01:00<00:20,  1.31it/s]
#
#
#
#  75%|████████████████████████████████████████████████████████████▎                    | 76/102 [01:01<00:19,  1.31it/s]
#
#
#
#  75%|█████████████████████████████████████████████████████████████▏                   | 77/102 [01:01<00:19,  1.30it/s]
#
#
#
#  76%|█████████████████████████████████████████████████████████████▉                   | 78/102 [01:02<00:18,  1.31it/s]
#
#
#
#  77%|██████████████████████████████████████████████████████████████▋                  | 79/102 [01:03<00:17,  1.30it/s]
#
#
#
#  78%|███████████████████████████████████████████████████████████████▌                 | 80/102 [01:04<00:16,  1.31it/s]
#
#
#
#  79%|████████████████████████████████████████████████████████████████▎                | 81/102 [01:04<00:15,  1.32it/s]
#
#
#
#  80%|█████████████████████████████████████████████████████████████████                | 82/102 [01:05<00:15,  1.32it/s]
#
#
#
#  81%|█████████████████████████████████████████████████████████████████▉               | 83/102 [01:06<00:14,  1.32it/s]
#
#
#
#  82%|██████████████████████████████████████████████████████████████████▋              | 84/102 [01:07<00:13,  1.32it/s]
#
#
#
#  83%|███████████████████████████████████████████████████████████████████▌             | 85/102 [01:07<00:12,  1.32it/s]
#
#
#
#  84%|████████████████████████████████████████████████████████████████████▎            | 86/102 [01:08<00:12,  1.31it/s]
#
#
#
#  85%|█████████████████████████████████████████████████████████████████████            | 87/102 [01:09<00:11,  1.31it/s]
#
#
#
#  86%|█████████████████████████████████████████████████████████████████████▉           | 88/102 [01:10<00:10,  1.30it/s]
#
#
#
#  87%|██████████████████████████████████████████████████████████████████████▋          | 89/102 [01:11<00:10,  1.29it/s]
#
#
#
#  88%|███████████████████████████████████████████████████████████████████████▍         | 90/102 [01:11<00:09,  1.28it/s]
#
#
#
#  89%|████████████████████████████████████████████████████████████████████████▎        | 91/102 [01:12<00:08,  1.29it/s]
#
#
#
#  90%|█████████████████████████████████████████████████████████████████████████        | 92/102 [01:13<00:07,  1.27it/s]
#
#
#
#  91%|█████████████████████████████████████████████████████████████████████████▊       | 93/102 [01:14<00:07,  1.28it/s]
#
#
#
#  92%|██████████████████████████████████████████████████████████████████████████▋      | 94/102 [01:14<00:06,  1.29it/s]
#
#
#
#  93%|███████████████████████████████████████████████████████████████████████████▍     | 95/102 [01:15<00:05,  1.29it/s]
#
#
#
#  94%|████████████████████████████████████████████████████████████████████████████▏    | 96/102 [01:16<00:04,  1.30it/s]
#
#
#
#  95%|█████████████████████████████████████████████████████████████████████████████    | 97/102 [01:17<00:03,  1.28it/s]
#
#
#
#  96%|█████████████████████████████████████████████████████████████████████████████▊   | 98/102 [01:18<00:03,  1.27it/s]
#
#
#
#  97%|██████████████████████████████████████████████████████████████████████████████▌  | 99/102 [01:18<00:02,  1.28it/s]
#
#
#
#  98%|██████████████████████████████████████████████████████████████████████████████▍ | 100/102 [01:19<00:01,  1.26it/s]
#
#
#
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 101/102 [01:20<00:00,  1.29it/s]
#
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 102/102 [01:21<00:00,  1.25it/s]
#    EventId   latitude  longitude  latitudeX  longitudeX  \
# 0    63216 -33.952298  18.465721    -33.952      18.466
# 1   138883 -33.888280  18.564370    -33.888      18.564
#
#                                              address               road  \
# 0  {'address29': "Mostert's Mill", 'road': 'Rhode...       Rhodes Drive
# 1  {'road': 'Giel Basson Drive', 'suburb': 'Kaapz...  Giel Basson Drive
#
#       suburb   town         state       city          suburb_long  \
# 0   Rosebank    NaN  Western Cape  Cape Town   Rosebank Cape Town
# 1  Kaapzicht  Parow  Western Cape        NaN  Kaapzicht Cape Town
#
#                                                 func
# 0  <geopy.extra.rate_limiter.RateLimiter object a...
# 1  <geopy.extra.rate_limiter.RateLimiter object a...

# %%
GeoDataMergedY['address_dict'] = GeoDataMergedY['func'].apply(lambda loc: loc.func.raw if loc else None)
#GeoDataMergedY = pd.concat([GeoDataMergedY,GeoDataY_unique_Suburb['address_dict'].apply(pd.Series)] ,axis=1)

# %%
GeoDataMergedY['address_dict'] = GeoDataMergedY['func'].apply(lambda loc: loc.func.raw if loc else None)
# Out:
#    EventId   latitude  longitude  latitudeX  longitudeX  \
# 0    63216 -33.952298  18.465721    -33.952      18.466
# 1   138883 -33.888280  18.564370    -33.888      18.564
# 2   140729 -33.906656  18.503528    -33.907      18.504
#
#                                              address               road  \
# 0  {'address29': "Mostert's Mill", 'road': 'Rhode...       Rhodes Drive
# 1  {'road': 'Giel Basson Drive', 'suburb': 'Kaapz...  Giel Basson Drive
# 2  {'road': 'Acre Road', 'suburb': 'Kensington', ...          Acre Road
#
#        suburb   town         state       city           suburb_long  \
# 0    Rosebank    NaN  Western Cape  Cape Town    Rosebank Cape Town
# 1   Kaapzicht  Parow  Western Cape        NaN   Kaapzicht Cape Town
# 2  Kensington    NaN  Western Cape  Cape Town  Kensington Cape Town
#
#                                                 func  \
# 0  <geopy.extra.rate_limiter.RateLimiter object a...
# 1  <geopy.extra.rate_limiter.RateLimiter object a...
# 2  <geopy.extra.rate_limiter.RateLimiter object a...
#
#                                         address_dict
# 0  {'place_id': 261097441, 'licence': 'Data © Ope...
# 1  {'place_id': 198464063, 'licence': 'Data © Ope...
# 2  {'place_id': 198565038, 'licence': 'Data © Ope...

# %%
GeoDataMergedY = pd.concat([GeoDataMergedY,GeoDataMergedY['address_dict'].apply(pd.Series)] ,axis=1)
GeoDataMergedY.head(3)
# Out:
#    EventId   latitude  longitude  latitudeX  longitudeX  \
# 0    63216 -33.952298  18.465721    -33.952      18.466
# 1   138883 -33.888280  18.564370    -33.888      18.564
# 2   140729 -33.906656  18.503528    -33.907      18.504
#
#                                              address               road  \
# 0  {'address29': "Mostert's Mill", 'road': 'Rhode...       Rhodes Drive
# 1  {'road': 'Giel Basson Drive', 'suburb': 'Kaapz...  Giel Basson Drive
# 2  {'road': 'Acre Road', 'suburb': 'Kensington', ...          Acre Road
#
#        suburb   town         state  ...  osm_type   osm_id  \
# 0    Rosebank    NaN  Western Cape  ...  relation  2034104
# 1   Kaapzicht  Parow  Western Cape  ...  relation  2051464
# 2  Kensington    NaN  Western Cape  ...  relation  2034993
#
#                                          boundingbox          lat         lon  \
# 0  [-33.9609345, -33.9499991, 18.4645707, 18.4834...  -33.9519444  18.4738889
# 1  [-33.8887422, -33.8792025, 18.5622216, 18.567914]  -33.8829439  18.5657386
# 2  [-33.9189134, -33.9032607, 18.4958044, 18.5152...  -33.9144444  18.5069444
#
#                                         display_name  class    type  \
# 0  Rosebank, Cape Town, City of Cape Town, Wester...  place  suburb
# 1  Kaapzicht, Parow, City of Cape Town, Western C...  place  suburb
# 2  Kensington, Cape Town, City of Cape Town, West...  place  suburb
#
#   importance                                               icon
# 0       0.36  https://nominatim.openstreetmap.org/images/map...
# 1       0.36  https://nominatim.openstreetmap.org/images/map...
# 2       0.36  https://nominatim.openstreetmap.org/images/map...
#
# [3 rows x 26 columns]

# %%
## Check if the returned adddress contains only SA's location
GeoDataMergedY.display_name.str.split(",").str[-1].value_counts()
# Out:
#  South Africa    102
# Name: display_name, dtype: int64

# %% [markdown]
# ### Get Geocordinate and bounding box of suburb

# %%
GeoDataMergedY = GeoDataMergedY[['suburb','boundingbox','lat','lon']]
GeoDataMergedY.head(3)
# Out:
#        suburb                                        boundingbox          lat  \
# 0    Rosebank  [-33.9609345, -33.9499991, 18.4645707, 18.4834...  -33.9519444
# 1   Kaapzicht  [-33.8887422, -33.8792025, 18.5622216, 18.567914]  -33.8829439
# 2  Kensington  [-33.9189134, -33.9032607, 18.4958044, 18.5152...  -33.9144444
#
#           lon
# 0  18.4738889
# 1  18.5657386
# 2  18.5069444

# %%
GeoDataMergedY.rename(columns={"lat": "latitude_suburb",
                                "lon": "longitude_suburb"
                                       },inplace=True)

# %%
GeoDataMergedY.head(3)
# Out:
#        suburb                                        boundingbox  \
# 0    Rosebank  [-33.9609345, -33.9499991, 18.4645707, 18.4834...
# 1   Kaapzicht  [-33.8887422, -33.8792025, 18.5622216, 18.567914]
# 2  Kensington  [-33.9189134, -33.9032607, 18.4958044, 18.5152...
#
#   latitude_suburb longitude_suburb
# 0     -33.9519444       18.4738889
# 1     -33.8829439       18.5657386
# 2     -33.9144444       18.5069444

# %%
GeoDataMergedY.to_csv("Data/Suburb_coordinate.csv", index=None)
